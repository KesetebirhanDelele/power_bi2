# %% [markdown]
# # Keep rows menu
#
# ![image.png](attachment:image.png)
#
# # Remove rows menu
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Remove alternate rows
#
# > Index column has been added and starts from 1
# > Starting position to remove rows: 1st row
# > Number of rows to remove counting from the first row to be removed: 2
# > Number of rows to keep after removing rows: 2
#
# Hence, 1,2 removed; 3,4 kept; 5,6 removed; 7,8 kept
#
# ![image.png](attachment:image.png)
