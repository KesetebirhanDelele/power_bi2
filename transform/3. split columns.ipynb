# %% [markdown]
# # Menu options
# ![image.png](attachment:image.png)
#
# # Split by positions
#
# > Split Zero to 15, then 15-20, etc
#
# Note that M language counts starting from 0 like python
#
# ![image-2.png](attachment:image-2.png)
