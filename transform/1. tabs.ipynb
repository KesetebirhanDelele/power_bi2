# %% [markdown]
# # Home tab
#
# > Note that 5 items from transform tab are present in the Home tab: split column, group by, use first row as column header, data type, and replace values by
#
# Note the grouping of functions:
# > Close
#
# > New Query
#
# > Data Sources
#
# > Parameters
#
# > Query
#
# > Manage Columns
#
# > Reduce Rows
#
# > Sort
#
# > Transform
#
# > Combine
#
# > AI Insights
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Transform tab
#
# Note groupings based on actions involving table, column, and data types:
#
# > Table
#
# > Any Column
#
# > Text Column
#
# > Number Column
#
# > Date and Time Column
#
# > Scripts
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Add Column tab
#
# Here are the groupings:
#
# > General
#
# > From Text
#
# > From Number
#
# > From Date & Time
#
# > AI Insights
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # View tab
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tools menu
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Help
#
# ![image.png](attachment:image.png)
