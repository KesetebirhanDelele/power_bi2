# %% [markdown]
# # Anomaly detection
#
# > Needs to have time series data
#
# > Needs line graphs only but only one line graph
#
# > It doesn't work if forcasting is activated
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
