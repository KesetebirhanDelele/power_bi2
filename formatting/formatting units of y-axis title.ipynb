# %% [markdown]
# # Y-axis style: tille vs unit
# ![image.png](attachment:image.png)

# %% [markdown]
# # Switch y-axis: in values option
#
# ![image.png](attachment:image.png)
#
# # Y-axis range: invert
# ![image-2.png](attachment:image-2.png)
