# %% [markdown]
# # Interactions:
#
# > where to edit it: format, edit interactions
#
# > Three options: filter, highlight (default), none
#
# > How to select multiple values in two different visuals:
#     >> use Ctrl or SHIFT
#
# ![image.png](attachment:image.png)
