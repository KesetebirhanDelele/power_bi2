# %% [markdown]
# # Page Formatting
#
# Note the difference between:
# > reddish color = wallpaper
#
# > yellowish color = canvas background
#
# > picutre in the canvas = image within cancas background
#
# Also note the transparency levels that enables the background color to be seen when it is zero (max) or
# anything below 100%. At 100%, those colours will not be seen
#
# ![image-2.png](attachment:image-2.png)
