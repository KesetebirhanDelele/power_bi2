# %% [markdown]
# # Reference lines
#
# ## Line, Bar, Column, area charts
#
# > min, max, average, median, percentile, constant
#
# ![image.png](attachment:image.png)
#
# ## Stacked and 100% Stacked charts
#
# > x axis constant line and constant line
#
# ![image-3.png](attachment:image-3.png)
#
# ## Combo charts like line-bar stacked or clustered
#
# > constant for the axis showing category eg: year
#
# ![image-2.png](attachment:image-2.png)
