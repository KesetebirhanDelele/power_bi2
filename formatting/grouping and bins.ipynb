# %% [markdown]
# # Grouping
#
# > Ctrl + select and group two categories of a bar chart
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Binning
#
# Right click a numeric variable and set options to re-categorize values
#
# ![image.png](attachment:image.png)
