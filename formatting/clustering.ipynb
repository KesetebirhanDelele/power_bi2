# %% [markdown]
# # Cluster analysis
#
# > Scatter plot used to do cluster analysis
#
# > A new variable is created by Power BI marking clustering date
#
# > Note that date hierarchy can't be used to make clusters
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Clustering process
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Cluster chart
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Editing Clusters
#
# ![image.png](attachment:image.png)
