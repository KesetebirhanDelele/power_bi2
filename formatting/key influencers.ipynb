# %% [markdown]
# # Key influencers
#
# > difference between explain by (determinant) and expand by (stratification)
#
#
#
# ![image.png](attachment:image.png)
#
# # Top segments
#
# ![image-2.png](attachment:image-2.png)
#
# ## Key influencer count type
#
# > absolute vs relative incidcates share of data with effect
#
# ![image-3.png](attachment:image-3.png)
