# %% [markdown]
# # User defined number format

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Example of millions formatting of a number column
#
# > Note that you can't make numerical calculations on such columns since theay are now numbers displayed as text
#
# ![image.png](attachment:image.png)
