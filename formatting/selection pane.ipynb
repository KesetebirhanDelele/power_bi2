# %% [markdown]
# # Selection pane
#
# > located in view tab
#
# > used to determine layer order,
#
# > tab order, and
#
# > determine visibility of visuals (located in layer order)
#
# ![image.png](attachment:image.png)
