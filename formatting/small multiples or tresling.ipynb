# %% [markdown]
# # Small multiples or tresling
#
# > allows to show graphs by categorical variable
# > graph types need to be bar, column, area, or line charts
#
# Eg sales by year stratified by region
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sorting by sales volume
# > The subtotal sales volume is used to sort small multiples graphs:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Small multiples layout
#
# How many rows and columns to view
#
# ![image.png](attachment:image.png)
