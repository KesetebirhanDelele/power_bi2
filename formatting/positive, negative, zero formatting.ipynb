# %% [markdown]
# # Positive, Negative, and Zero formatting for numerical columns in Power BI

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Negative number in a brace with thousand separater
#
# ![image.png](attachment:image.png)
