# %% [markdown]
# # Ribon charts
#
# > Used to trace comparison between different charts
#
# > Note space between trends and ribons settings
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Waterfall charts
#
# > Used to trace trend of gain and loss
#
# > Used to trace cumulative progress
#
# > Breakdown settings: used to focus trend for top 3 contributers as in the example below
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Scatter plot
#
# ## Static Scatter plot with sales volume by average % 12 month change for each year by region
#
# ![image.png](attachment:image.png)
#
# ## Dynamic Scatter plot with year as play axis
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Bubble chart
#
# > Scatter plot with sales volume specifiying bubble size
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Dot plot
#
# > Uses categorical variable on the X axis and nothing on the play axis or values
#
# > Eg for each area code, avg % 12 month change and volume (size of Dot) are plotted
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Bubble chart with trail
#
# ![image.png](attachment:image.png)
