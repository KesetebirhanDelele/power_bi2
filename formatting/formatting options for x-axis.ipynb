# %% [markdown]
# # Formatting options for X axis:
#
# > Continous vs categorical: figure below is continous while the one below that is categorical
# ![image-2.png](attachment:image-2.png)
#
# > Concatenate labels works for categorical type of variable
# ![image.png](attachment:image.png)
